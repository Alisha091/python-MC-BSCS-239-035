# %%
#print simple program
print("Hello, World!")
# Out:
# Hello, World!

# %%
#print numbers
print(102)
# Out:
# 102

# %%
#declare a simple variable and assign value
x = 23
y = "Alisha"
z = 5.5
print(x)
print(y)
print(z)
# Out:
# 23
# Alisha
# 5.5

# %%
#perform simple arithmatic operations
print(3+5)
# Out:
# 8

# %%
#declare variable and perform arithmatic operations
x = 4
y = 10
z = x + y 
a = x - y
b = x * y
c = a + b
print(z)
print(a)
print(b)
print(c)
# Out:
# 14
# -6
# 40
# 34

# %%
#multiple variables with same value
x= y= z= 12
print(y)
print(x)
print(z)
# Out:
# 12
# 12
# 12

# %%
#multiple variables with multiple values
x , y, z = 12 , 14, 50
print(x)
print(y)
print(z)
# Out:
# 12
# 14
# 50

# %%
#print string with text values
Age = "My age is: "
x = 23
print(Age, x)
# Out:
# My age is:  23
